# %% [markdown]
# # 🐍 Python Level 2 - Intermediate course
# ## Class 3 — Data Visualisation
# ### 📝 Practice Exercises
#
# **Python instructor - Catarina Santos**
#
# ---
#
# <div style="display:inline-flex; align-items:center; gap:28px; background:#FFFFFF; color:#1D1D1B; padding:10px 14px; border-radius:8px; margin-bottom:8px;"><img src="data:image/png;base64,..." alt="Natixis" height="52" style="object-fit:contain;"/><img src="data:image/png;base64,..." alt="Porto Executive Academy" height="62" style="object-fit:contain;"/></div>
#
# ---

# %% [markdown]
# ---
#
# Work through the sections in order the difficulty increases as you go.
#
# | Section | Difficulty | Topics |
# |---------|------------|--------|
# | A | 🟢 Warm-up | `plt.plot`, styling, labels, legend |
# | B | 🟡 Core practice | bar, barh, histogram, scatter |
# | C | 🟠 Applied | charts from a DataFrame, seaborn |
# | D | 🔴 Challenge | a dashboard, and saving it |
#
# > 💡 **A chart cannot be checked by comparing text**, so instead of an expected output each
# > exercise says exactly **what your chart must show**. Work down the checklist and compare it
# > with what appears under your cell.
#
# > 💡 From A3 onwards, **every chart needs a title and labelled axes.** If a marker is missing
# > from your checklist, that is the first thing to look for.
#
# > 💡 **Before you start:** put `expenses.csv` in your Google Drive since Section C needs it.
#
# ---

# %% [markdown]
# ## ⚙️ Setup
#
# Run this cell first.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
visitors = [120, 95, 140, 160, 210]
visitors_last_week = [110, 105, 125, 145, 185]
sales = [820, 610, 980, 1150, 1480]

products = ["Coffee", "Tea", "Cake", "Juice", "Sandwich"]
units = [340, 210, 180, 95, 260]

basket_values = [3.20, 4.10, 4.50, 5.00, 5.40, 5.90, 6.30, 6.80, 7.10, 7.60,
                 8.20, 8.80, 9.40, 10.10, 11.30, 12.00, 13.50, 15.20,
                 17.80, 19.40, 22.10, 25.60, 29.00, 34.50]

print("Setup complete:", len(days), "days and", len(basket_values), "baskets")

# %% [markdown]
# ---
# ## 🟢 Section A — Warm-up
# ### `plt.plot`, styling, labels, legend
#
# > 🕐 Estimated time: 15 min

# %% [markdown]
# ### Exercise A1 — Your first chart
#
# Draw a line chart of `visitors` against `days`.
#
# Your chart must show:
# - A line with 5 points, rising from Mon to Fri with a dip on Tue
# - `Mon Tue Wed Thu Fri` along the bottom
#
# > 💡 Two calls: `plt.plot(x, y)` then `plt.show()`.

# %%
# A1

# %% [markdown]
# ### Exercise A2 — Style the line
#
# Draw the same chart again, but make the line **green**, **dashed**, **2 thick**, with a **dot at
# each point**.
#
# Your chart must show:
# - The same shape as A1
# - A green dashed line with a visible marker at each of the 5 points
#
# > 💡 Four keyword arguments on `plt.plot`: `color=`, `linestyle=`, `linewidth=`, `marker=`.

# %%
# A2

# %% [markdown]
# ### Exercise A3 — Label it properly
#
# Draw the visitors chart one more time, properly finished.
#
# Your chart must show:
# - A canvas 8 by 4, with a marker at each point
# - The title `Visitors per day`
# - `Day` under the x-axis and `Visitors` beside the y-axis
# - Gridlines
#
# > ⚠️ Everything must be called **before** `plt.show()` since it clears the figure.

# %%
# A3

# %% [markdown]
# ### Exercise A4 — Two lines and a legend
#
# Compare this week with last week on one chart.
#
# Your chart must show:
# - Two lines: `visitors` and `visitors_last_week`
# - Different markers, and last week **dashed**
# - A **legend** naming them `This week` and `Last week`
# - Title `Visitors: this week against last`, axes labelled, gridlines
#
# > 💡 Call `plt.plot()` twice before one `plt.show()`. Give each a `label=`, then call
# > `plt.legend()` without the labels, the legend has nothing to show.

# %%
# A4

# %% [markdown]
# ---
# ## 🟡 Section B — Core practice
# ### The four chart types
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise B1 — Bar chart
#
# Show `units` per product as a bar chart.
#
# Your chart must show:
# - 5 bars, all one colour, tallest for Coffee and shortest for Juice
# - Product names under the bars
# - Title `Units sold by product`, y-axis labelled `Units`

# %%
# B1

# %% [markdown]
# ### Exercise B2 — Horizontal bar chart
#
# The same data, but **horizontal**.
#
# Your chart must show:
# - 5 horizontal bars with the product names down the left
# - Title `Units sold by product`, x-axis labelled `Units`
#
# > 💡 `plt.barh()`. Note the axis labels swap over the values are now along the bottom.

# %%
# B2

# %% [markdown]
# ### Exercise B3 — Histogram
#
# Show how `basket_values` are spread, using **6 bins**.
#
# Your chart must show:
# - 6 bars, tallest on the left and falling away to the right most baskets are small
# - Title `How basket values are spread`
# - x-axis `Basket value (EUR)`, y-axis `How many baskets`
#
# > 💡 A histogram takes **one** list, not two: `plt.hist(basket_values, bins=6)`.

# %%
# B3

# %% [markdown]
# ### Exercise B4 — Scatter
#
# Do more visitors mean more sales? Put `visitors` against `sales`.
#
# Your chart must show:
# - 5 separate points, no line joining them
# - The points running up and to the right since more visitors does mean more sales
# - Title `Do more visitors mean more sales?`, both axes labelled, gridlines

# %%
# B4

# %% [markdown]
# ---
# ## 🟠 Section C — Applied
# ### Charts from a DataFrame, and seaborn
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise C1 — Load, clean, and chart a month trend
#
# Load `expenses.csv` in your Google Colab folder, then clean it: drop the
# duplicates, lower-case the `department`, drop the `notes` column, and drop the rows with no
# `actual`. Print the shape.
#
# Then `groupby` month, total the `actual`, print it, and draw it as a line chart.
#
# Printed output:
# ```
# (141, 5)
# ```
#
# Your chart must show:
# - A line with 6 points, one per month, dipping in February and March and peaking in April
# - Title `Actual spend by month`, axes labelled, gridlines
#
# > 💡 A grouped result has `.index` (the months) and `.values` (the numbers) those are the two
# > lists `plt.plot()` wants.

# %%
# C1

# %% [markdown]
# ### Exercise C2 — A chart in one line, with `df.plot()`
#
# Total the `actual` per `category`, sort it **biggest first**, print it, then chart it with
# `.plot(kind="bar")` instead of matplotlib.
#
# Your chart must show:
# - 5 bars in descending height, Software tallest and Travel shortest
# - Title `Total actual spend by category`, y-axis `EUR`
# - The category names readable, not overlapping
#
# > 💡 `.plot()` takes `kind=`, `figsize=` and `color=`. You still add the title with
# > `plt.title()` afterwards, and `plt.tight_layout()` stops the labels being cut off.

# %%
# C2

# %% [markdown]
# ### Exercise C3 — Two seaborn charts
#
# Apply `sns.set_style("whitegrid")`, then draw two charts straight from the DataFrame:
#
# 1. A **countplot** of `department` — how many spend lines each one has
# 2. A **boxplot** of `actual` by `category` — how the individual amounts spread out
#
# Your charts must show:
# - Countplot: 5 bars of roughly equal height, around 28 each
# - Boxplot: 5 boxes, each with a line inside it and whiskers reaching up and down
# - A title on each, and `EUR` on the boxplot's y-axis
#
# > 💡 seaborn reads the DataFrame directly:
# > `sns.boxplot(data=expenses, x="category", y="actual")`.

# %%
# C3

# %% [markdown]
# ---
# ## 🔴 Section D — Challenge
# ### A dashboard, and saving it
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise D1 — A four-chart dashboard
#
# Build **one figure** with four charts in a 2x2 grid, on an 11 by 7 canvas:
#
# | Position | Chart |
# |----------|-------|
# | top left | spend by month — a **line** |
# | top right | spend by department — a **horizontal bar** |
# | bottom left | the spread of `budget` — a **histogram**, 10 bins |
# | bottom right | `budget` against `actual` — a **scatter** |
#
# Your figure must show:
# - Four charts in a 2x2 grid, none overlapping
# - A title on every one, and labelled axes
# - The month labels rotated so they fit
# - The scatter's points forming a rising band where bigger budgets do mean bigger actuals
#
# > 💡 `plt.subplot(2, 2, position)` before each chart, and `plt.tight_layout()` once at the end,
# > just before `plt.show()`.

# %%
# D1

# %% [markdown]
# ### Exercise D2 — Answer one question, and save the chart
#
# **The sentence comes first:** *"Operations went furthest over budget; HR spent well under."*
# Build the one chart that proves it.
#
# 1. Add a `difference` column — `actual` minus `budget`, rounded to 2 decimals
# 2. Total it per department, sort **biggest first**, and print it
# 3. Draw it as a bar chart with a dashed grey line at **zero**
# 4. Save it as `budget_variance.png` at `dpi=150`, then show it
#
# Your chart must show:
# - 5 bars, the leftmost tallest and **positive**, the rightmost clearly **negative**
# - A dashed horizontal line at zero, so over and under budget are obvious at a glance
# - Title `Over and under budget by department`, y-axis `Actual minus budget (EUR)`
#
# > 💡 `plt.axhline(y=0, color="grey", linestyle="--")` draws the reference line.
# >
# > 💡 `plt.savefig(...)` must come **before** `plt.show()`. After it, the figure is empty and
# > you will save a blank image. This catches everybody once.

# %%
# D2

# %% [markdown]
# ---
#
# ### 🎉 Well done!
#
# You have now practised every concept from Class 3 of Level 2:
#
# | | Concept | Exercises |
# |-|---------|----------|
# | ✅ | `plt.plot` and `plt.show` | A1 |
# | ✅ | Styling a line | A2 |
# | ✅ | Title, axis labels, grid | A3 onwards |
# | ✅ | Two series and a legend | A4 |
# | ✅ | Bar and horizontal bar | B1, B2, D1 |
# | ✅ | Histogram | B3, D1 |
# | ✅ | Scatter | B4, D1 |
# | ✅ | Charting a `groupby` result | C1, C2, D1, D2 |
# | ✅ | `df.plot(kind=...)` | C2 |
# | ✅ | seaborn `countplot`, `boxplot` | C3 |
# | ✅ | `subplot` and `tight_layout` | D1 |
# | ✅ | `axhline` and `savefig` | D2 |
#
# ➡️ The solutions notebook will be shared after the class. Practice first and learn by doing!
