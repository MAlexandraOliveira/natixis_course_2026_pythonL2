# %% [markdown]
# # 🐍 Python Level 2 - Intermediate course
# ## Class 2 — Comprehensions and Built-in Functions
# ### 📝 Practice Exercises
#
# **Python instructor - Luis Dias**
#
# ---
#
# <div style="display:inline-flex; align-items:center; gap:28px; background:#FFFFFF; color:#1D1D1B; padding:10px 14px; border-radius:8px; margin-bottom:8px;"><img src="data:image/png;base64,..." alt="Natixis" height="52" style="object-fit:contain;"/><img src="data:image/png;base64,..." alt="Porto Executive Academy" height="62" style="object-fit:contain;"/></div>
#
# ---

# %% [markdown]
# ---
#
# Work through the sections in order since the difficulty increases as you go.
#
# | Section | Difficulty | Topics |
# |---------|------------|--------|
# | A | 🟢 Warm-up | list comprehensions |
# | B | 🟡 Core practice | dict and set comprehensions, `lambda` |
# | C | 🟠 Applied | `sorted` with a key, `map`, `filter` |
# | D | 🔴 Challenge | `zip`, `any`, `all`, and a full summary |
#
# > 💡 **Write the loop first if it helps.** Get it working, then collapse it into one line. That
# > is how experienced programmers write comprehensions too.
#
# > 💡 A **set** has no order, so an exercise that builds one asks you to print it `sorted(...)`.
# > That is why those expected outputs show square brackets.
#
# ---

# %% [markdown]
# ## ⚙️ Setup
#
# Run this cell first. Every exercise uses `numbers` or `cities`.

# %%
numbers = [4, 11, 7, 22, 9, 30, 2]

cities = [
    {"name": "Porto",    "population": 231962, "country": "Portugal", "coastal": True},
    {"name": "Lisbon",   "population": 545923, "country": "Portugal", "coastal": True},
    {"name": "Madrid",   "population": 3223334, "country": "Spain",   "coastal": False},
    {"name": "Seville",  "population": 684025, "country": "Spain",    "coastal": False},
    {"name": "Bordeaux", "population": 257068, "country": "France",   "coastal": False},
]

print("Setup complete:", len(numbers), "numbers and", len(cities), "cities")

# %% [markdown]
# ---
# ## 🟢 Section A — Warm-up
# ### List comprehensions
#
# > 🕐 Estimated time: 15 min

# %% [markdown]
# ### Exercise A1 — Your first comprehension
#
# Using a comprehension, build a list of every number in `numbers` **doubled**, and print it.
#
# Expected output:
# ```
# [8, 22, 14, 44, 18, 60, 4]
# ```

# %%
# A1

# %% [markdown]
# ### Exercise A2 — A comprehension with a condition
#
# Print two lists:
#
# 1. The numbers **greater than 10**
# 2. The **even** numbers
#
# Expected output:
# ```
# [11, 22, 30]
# [4, 22, 30, 2]
# ```
#
# > 💡 A number is even when `number % 2 == 0`.

# %%
# A2

# %% [markdown]
# ### Exercise A3 — Transform and filter at once
#
# Build a list of the **squares** of the numbers **under 10**, and print it.
#
# Expected output:
# ```
# [16, 49, 81, 4]
# ```
#
# > 💡 The calculation goes at the front, the test at the back:
# > `[... for number in numbers if ...]`. `number ** 2` squares it.

# %%
# A3

# %% [markdown]
# ### Exercise A4 — One field out of a list of dicts
#
# Print two lists:
#
# 1. The `name` of every city
# 2. The `name` of only the **coastal** cities
#
# Expected output:
# ```
# ['Porto', 'Lisbon', 'Madrid', 'Seville', 'Bordeaux']
# ['Porto', 'Lisbon']
# ```
#
# > 💡 `city["coastal"]` is already `True` or `False`, so it can be the whole condition. You do
# > not need `== True`.

# %%
# A4

# %% [markdown]
# ---
# ## 🟡 Section B — Core practice
# ### Dict and set comprehensions, `lambda`
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise B1 — A dict comprehension
#
# Build a dictionary `populations` mapping each city **name** to its **population**. Print it,
# then print Madrid's population by looking it up.
#
# Expected output:
# ```
# {'Porto': 231962, 'Lisbon': 545923, 'Madrid': 3223334, 'Seville': 684025, 'Bordeaux': 257068}
# 3223334
# ```
#
# > 💡 Curly brackets, and a colon between the key and the value:
# > `{city["name"]: city["population"] for city in cities}`.

# %%
# B1

# %% [markdown]
# ### Exercise B2 — A dict comprehension with a condition
#
# Build the same kind of dictionary, but only for the cities in **Portugal**. Print it.
#
# Expected output:
# ```
# {'Porto': 231962, 'Lisbon': 545923}
# ```

# %%
# B2

# %% [markdown]
# ### Exercise B3 — A set comprehension
#
# Build a set of the distinct **countries**. Print it **sorted**, then print how many there are.
#
# Expected output:
# ```
# ['France', 'Portugal', 'Spain']
# 3
# ```

# %%
# B3

# %% [markdown]
# ### Exercise B4 — Lambdas
#
# Write three lambdas and print a result from each:
#
# 1. `triple` — multiplies its argument by 3. Print `triple(7)`
# 2. `area` — takes a width and a height and multiplies them. Print `area(3, 4)`
# 3. `is_big` — returns `True` when its argument is over 10. Print `is_big(22)` and `is_big(4)`
#    on one line
#
# Expected output:
# ```
# 21
# 12
# True False
# ```
#
# > ⚠️ A lambda holds **one expression** and there is no `return` since the expression is the result.

# %%
# B4

# %% [markdown]
# ---
# ## 🟠 Section C — Applied
# ### `sorted` with a key, `map`, `filter`
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise C1 — Sorting with a key
#
# Print the city **names** in two orders:
#
# 1. Sorted by **population**, smallest first
# 2. Sorted by **name**, alphabetically
#
# Expected output:
# ```
# ['Porto', 'Bordeaux', 'Lisbon', 'Seville', 'Madrid']
# ['Bordeaux', 'Lisbon', 'Madrid', 'Porto', 'Seville']
# ```
#
# > 💡 `sorted(cities, key=lambda city: city["population"])` sorts the **dicts**; you then need a
# > comprehension to pull the names out for printing.

# %%
# C1

# %% [markdown]
# ### Exercise C2 — Sorting the other way, and taking the top few
#
# 1. Print the names of the **two largest** cities by population
# 2. Print `numbers` sorted **biggest first**
# 3. Print `numbers` again, to show `sorted()` left it alone
#
# Expected output:
# ```
# ['Madrid', 'Seville']
# [30, 22, 11, 9, 7, 4, 2]
# [4, 11, 7, 22, 9, 30, 2]
# ```
#
# > 💡 Sort with `reverse=True`, then take the first two with a slice — `[:2]`.

# %%
# C2

# %% [markdown]
# ### Exercise C3 — `map` and `filter`
#
# Print three lists:
#
# 1. Every number **times 10**, using `map` and a lambda
# 2. The numbers **over 10**, using `filter` and a lambda
# 3. The numbers over 10, times 10 as a **single comprehension**
#
# Expected output:
# ```
# [40, 110, 70, 220, 90, 300, 20]
# [11, 22, 30]
# [110, 220, 300]
# ```
#
# > 💡 `map` and `filter` need `list(...)` around them to print as a list. Compare how the third
# > line reads against the first two and that is why comprehensions usually win.

# %%
# C3

# %% [markdown]
# ### Exercise C4 — Population in thousands
#
# Build a dictionary mapping each city name to its population **in thousands**, rounded to a
# whole number. Print it.
#
# Expected output:
# ```
# {'Porto': 232, 'Lisbon': 546, 'Madrid': 3223, 'Seville': 684, 'Bordeaux': 257}
# ```
#
# > 💡 `round(value)` with no second argument gives a whole number.

# %%
# C4

# %% [markdown]
# ---
# ## 🔴 Section D — Challenge
# ### `zip`, `any`, `all`, and a full summary
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise D1 — `zip`, `any` and `all`
#
# 1. Build two lists with comprehensions: the city `names` and their `populations`
# 2. Use `zip` to print them as a table with name padded to 10, population right-aligned in 9 with
#    thousands separators
# 3. Print the list of `coastal` flags, then whether **any** city is coastal, whether **all**
#    are, whether **any** has over a million people, and whether **all** have over 100,000
#
# Expected output:
# ```
# Porto       231,962
# Lisbon      545,923
# Madrid    3,223,334
# Seville     684,025
# Bordeaux    257,068
#
# [True, True, False, False, False]
# Any coastal? True
# All coastal? False
# Any over 1m? True
# All over 100k? True
# ```
#
# > 💡 The table line is `f"{name:<10}{population:>9,}"`. The `,` in a format specifier adds the
# > thousands separators.
# >
# > 💡 `any()` and `all()` can read a comprehension directly:
# > `any(population > 1000000 for population in populations)` where no square brackets are needed.

# %%
# D1

# %% [markdown]
# ### Exercise D2 — City report
#
# Put the whole class together in one cell. Build:
#
# 1. `large_names` — a list of the names with a population over `POPULATION_LIMIT` (500000)
# 2. `lookup` — a dict of name → population
# 3. `countries` — a set of the distinct countries
# 4. `by_population` — the cities sorted **largest first**, and `top_two` from it
# 5. `total` and `average` population, from a comprehension of the populations
# 6. A table of all the cities, largest first, built with `zip` from two lists
# 7. A summary block including an `all` check on coastal and an `any` check for France
#
# Expected output:
# ```
# CITY REPORT (largest first)
# ------------------------------
# Madrid     3,223,334
# Seville      684,025
# Lisbon       545,923
# Bordeaux     257,068
# Porto        231,962
# ------------------------------
# Cities        : 5
# Countries     : ['France', 'Portugal', 'Spain']
# Over 500k     : ['Lisbon', 'Madrid', 'Seville']
# Top two       : ['Madrid', 'Seville']
# Total         : 4,942,312
# Average       : 988,462
# All coastal?  : False
# Any in France?: True
# ```
#
# > 💡 For the table, build `names` from `by_population` and then
# > `sorted_populations = [lookup[name] for name in names]` a comprehension that uses your own
# > dictionary as a lookup. The table line is `f"{name:<10}{population:>10,}"` and the separator
# > is `"-" * 30`.
# >
# > 💡 Inside an f-string you need the other kind of quotes: `{city['coastal']}`, not
# > `{city["coastal"]}`.

# %%
# D2
POPULATION_LIMIT = 500000

# %% [markdown]
# ---
#
# ### 🎉 Well done!
#
# You have now practised every concept from Class 2 of Level 2:
#
# | | Concept | Exercises |
# |-|---------|----------|
# | ✅ | List comprehension | A1, A4 |
# | ✅ | …with a condition | A2, A4 |
# | ✅ | …transform and filter | A3 |
# | ✅ | Dict comprehension | B1, B2, C4 |
# | ✅ | Set comprehension | B3 |
# | ✅ | `lambda` | B4, C1, C2, C3 |
# | ✅ | `sorted` with `key` | C1, C2 |
# | ✅ | `reverse=True` and slicing | C2 |
# | ✅ | `map` and `filter` | C3 |
# | ✅ | `zip` | D1, D2 |
# | ✅ | `any` and `all` | D1, D2 |
#
# ➡️ The solutions notebook will be shared after the class. Practice first and learn by doing!
