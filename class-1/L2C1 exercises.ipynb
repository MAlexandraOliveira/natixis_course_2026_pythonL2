# %% [markdown]
# # 🐍 Python Level 2 - Intermediate course
# ## Class 1 — Functions
# ### 📝 Practice Exercises
#
# **Python instructor - Luis Dias**
#
# ---
#
# <div style="display:inline-flex; align-items:center; gap:28px; background:#FFFFFF; color:#1D1D1B; padding:10px 14px; border-radius:8px; margin-bottom:8px;"><img src="data:image/png;base64,..." alt="Natixis" height="52" style="object-fit:contain;"/><img src="data:image/png;base64,..." alt="Porto Executive Academy" height="62" style="object-fit:contain;"/></div>
#
# ---

# %% [markdown]
# ---
#
# Work through the sections in order since the difficulty increases as you go.
#
# | Section | Difficulty | Topics |
# |---------|------------|--------|
# | A | 🟢 Warm-up | defining, calling, `return` |
# | B | 🟡 Core practice | defaults, keyword arguments, scope |
# | C | 🟠 Applied | functions over data structures |
# | D | 🔴 Challenge | a pipeline of functions |
#
# > 💡 **Give every function a docstring** one line in triple quotes saying what it does. It
# > takes five seconds and it is the difference between code you can come back to and code you
# > cannot.
#
# > 💡 If a function is meant to `return` something and you get `None`, you almost certainly
# > wrote `print()` where you meant `return`.
#
# ---

# %% [markdown]
# ## ⚙️ Setup
#
# Run this cell first.

# %%
print("Setup complete - let's write some functions!")

# %% [markdown]
# ---
# ## 🟢 Section A — Warm-up
# ### Defining, calling, `return`
#
# > 🕐 Estimated time: 15 min

# %% [markdown]
# ### Exercise A1 — Your first function
#
# Write a function `greet()` that takes nothing and **prints** `Hello from a function!`.
# Then call it **twice**.
#
# Expected output:
# ```
# Hello from a function!
# Hello from a function!
# ```

# %%
# A1

# %% [markdown]
# ### Exercise A2 — A function with a parameter
#
# Write `greet_person(name)` that prints `Hello, <name>!`. Call it for `"Ana"` and `"Bruno"`.
#
# Expected output:
# ```
# Hello, Ana!
# Hello, Bruno!
# ```

# %%
# A2

# %% [markdown]
# ### Exercise A3 — `return` instead of `print`
#
# Write `double(number)` that **returns** twice the number. It must not print anything itself.
#
# Then print `double(7)`, and on the next line print `double(7) + double(3)`.
#
# Expected output:
# ```
# 14
# 20
# ```
#
# > 💡 That second line is the whole point of `return`: you can only add up two results if the
# > function hands them back.

# %%
# A3

# %% [markdown]
# ### Exercise A4 — Two parameters
#
# Write `rectangle_area(width, height)` that returns the area. Print it for `4, 5` and for
# `2.5, 3`.
#
# Expected output:
# ```
# 20
# 7.5
# ```

# %%
# A4

# %% [markdown]
# ---
# ## 🟡 Section B — Core practice
# ### Defaults, keyword arguments, scope
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise B1 — A default argument
#
# Write `add_vat(amount, rate=23)` that returns the amount with VAT added, rounded to 2 decimals.
#
# Print it three times: for `100` with no rate given, for `100` at a rate of `6`, and for `59.90`.
#
# Expected output:
# ```
# 123.0
# 106.0
# 73.68
# ```

# %%
# B1

# %% [markdown]
# ### Exercise B2 — Keyword arguments
#
# Write `book_room(nights, guests=1, breakfast=False)` that **returns** the line
# `nights: 3, guests: 1, breakfast: False`.
#
# Call it four times: with only the nights; with nights and guests by position; with `nights` and
# `breakfast` by name; and with all three by name **in a jumbled order**.
#
# Expected output:
# ```
# nights: 3, guests: 1, breakfast: False
# nights: 3, guests: 2, breakfast: False
# nights: 3, guests: 1, breakfast: True
# nights: 2, guests: 4, breakfast: True
# ```
#
# > 💡 The last call is the point: once you name the values, the order stops mattering.

# %%
# B2

# %% [markdown]
# ### Exercise B3 — Local and global
#
# A global `discount_rate = 10` is given below.
#
# 1. Write `apply_discount(price)` that works out the saving **inside** the function, in a local
#    variable called `saving`, and returns the discounted price rounded to 2 decimals
# 2. Print `apply_discount(80)`
# 3. Print `discount_rate` afterwards, to show the call did not change it
# 4. Add a **commented-out** `print(saving)` with a note saying why it would fail, then print
#    `saving does not exist outside the function`
#
# Expected output:
# ```
# 72.0
# 10
# saving does not exist outside the function
# ```

# %%
# B3
discount_rate = 10

# %% [markdown]
# ### Exercise B4 — A function that answers yes or no
#
# Write `is_expensive(price, limit=50)` that returns `True` when the price is above the limit.
#
# Print it for `80`, for `20`, and for `20` with a limit of `10`. Then use it directly inside an
# `if` to print `Needs approval` for a price of `120`.
#
# Expected output:
# ```
# True
# False
# True
# Needs approval
# ```
#
# > 💡 `price > limit` already **is** `True` or `False` just return it. No `if` needed inside
# > the function.

# %%
# B4

# %% [markdown]
# ---
# ## 🟠 Section C — Applied
# ### Functions over data structures
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise C1 — A function that takes a list
#
# Write `total_of(numbers)` that returns the total of a list of numbers, rounded to 2 decimals.
# Build it with the running-total pattern from Level 1: start at `0` and add each item with `+=`.
#
# Print it for `[8.50, 12.00, 2.10]`, for `[100, 200]`, and for an **empty list**.
#
# Expected output:
# ```
# 22.6
# 300
# 0
# ```

# %%
# C1

# %% [markdown]
# ### Exercise C2 — A function that takes a dictionary
#
# Write `describe_customer(customer)` that takes a customer dict and returns the line
# `Ana Silva from Porto has 3 orders`.
#
# Call it for both customers below.
#
# Expected output:
# ```
# Ana Silva from Porto has 3 orders
# Bruno Costa from Lisbon has 12 orders
# ```

# %%
# C2
ana = {"name": "Ana Silva", "city": "Porto", "orders": 3}
bruno = {"name": "Bruno Costa", "city": "Lisbon", "orders": 12}

# %% [markdown]
# ### Exercise C3 — A function that returns a dictionary
#
# Write `describe_numbers(numbers)` that returns a **dictionary** with the keys `count`, `total`,
# `smallest`, `largest` and `average` rounded to 2 decimals.
#
# Print the whole dictionary for `[8.50, 12.00, 2.10, 45.00]`, then print just the average from
# it.
#
# Expected output:
# ```
# {'count': 4, 'total': 67.6, 'smallest': 2.1, 'largest': 45.0, 'average': 16.9}
# 16.9
# ```
#
# > 💡 A function can `return` a whole dict. Write the `{` on the `return` line and build it
# > there.

# %%
# C3

# %% [markdown]
# ---
# ## 🔴 Section D — Challenge
# ### A pipeline of functions
#
# > 🕐 Estimated time: 25 min

# %% [markdown]
# ### Exercise D1 — Functions calling functions
#
# Write three functions and use them together:
#
# 1. `clean_title(title)` — returns the title with stray spaces removed
# 2. `shipping_cost(weight_kg)` — returns `2.50` EUR per kg, but **never less than 5.00**
# 3. `describe_parcel(parcel)` — takes a parcel dict and returns one line, using the other two
#
# Then loop over the parcels and print a line for each.
#
# Expected output:
# ```
# Dune                   5.00 EUR
# Python Basics          7.50 EUR
# Atlas of Ports        31.00 EUR
# ```
#
# > 💡 The line is `f"{title:<20}{cost:>7.2f} EUR"`.
# >
# > 💡 In `shipping_cost()`, work out the cost first, then `return 5.00` if it came out under
# > a `return` stops the function immediately, so you do not need an `else`.

# %%
# D1
parcels = [
    {"title": "  Dune ", "weight_kg": 0.8},
    {"title": "Python Basics", "weight_kg": 3.0},
    {"title": " Atlas of Ports", "weight_kg": 12.4},
]

# %% [markdown]
# ### Exercise D2 — A complete library report
#
# Put the whole class together. Write four functions:
#
# 1. `clean_title(title)` — spaces removed
# 2. `classify_length(pages)` — `short` up to 200, `medium` up to 500, `long` above 500
# 3. `describe_book(book)` — one report line, using the other two
# 4. `summarise_books(books)` — loops the books and **returns a dict** with the counts of
#    `short`, `medium` and `long`, plus `total_pages`
#
# Then print the report and the summary.
#
# Expected output:
# ```
# LIBRARY REPORT
# ----------------------------------
# Dune                412  medium
# Python Basics       180  short
# Atlas of Ports      640  long
# Short Stories        95  short
# The Long Road       720  long
# ----------------------------------
# short             2
# medium            1
# long              2
# total pages    2047
# ```
#
# > 💡 Put the two page limits in named variables at the top, like `SHORT_LIMIT = 200`. Then try
# > changing one and re-running.
# >
# > 💡 The report line is `f"{title:<18}{book['pages']:>5}  {classify_length(book['pages'])}"`,
# > and the summary lines are `f"{size:<14}{summary[size]:>5}"`. The separator is `"-" * 34`.
# >
# > 💡 In `summarise_books()`, start `counts = {"short": 0, "medium": 0, "long": 0}` and then
# > `counts[classify_length(book["pages"])] += 1` adds one to the right key in a single line.

# %%
# D2
books = [
    {"title": "  Dune ", "pages": 412},
    {"title": "Python Basics", "pages": 180},
    {"title": " Atlas of Ports", "pages": 640},
    {"title": "Short Stories ", "pages": 95},
    {"title": "The Long Road", "pages": 720},
]

# %% [markdown]
# ---
#
# ### 🎉 Well done!
#
# You have now practised every concept from Class 1 of Level 2:
#
# | | Concept | Exercises |
# |-|---------|----------|
# | ✅ | `def` and calling | A1, A2 |
# | ✅ | `return` vs `print` | A3 |
# | ✅ | Several parameters | A4 |
# | ✅ | Default arguments | B1, B2, B4 |
# | ✅ | Keyword arguments | B2 |
# | ✅ | Local and global | B3 |
# | ✅ | Returning `True`/`False` | B4 |
# | ✅ | A function over a list | C1 |
# | ✅ | A function over a dict | C2 |
# | ✅ | Returning a dict | C3 |
# | ✅ | Functions calling functions | D1, D2 |
# | ✅ | Docstrings | every one |
#
# ➡️ The solutions notebook will be shared after the class. Practice first and learn by doing!
